# %%
import numpy as np 
import pandas as pd

# %%
colnames=['checkingAccount' , 'DurationMonths','CreditHistory','Purpose',
         'CreditAmount', 'SavingAccounts', 'PresentEmployment', 'InstallmentRate',
          'PersonalStatus', 'OtherDebtors', 'PresentResidence', 'Property',
         'Age','OtherInstallmentPlans','Housing', 'ExistingCredits', 'Job',
         'Liables','Telephone','ForeignWorker','Class']

# %%
df=pd.read_csv("germandata.csv",  names=colnames)

# %%
df.head()
# Out:
#   checkingAccount  DurationMonths CreditHistory Purpose  CreditAmount  \
# 0             A11               6           A34     A43          1169
# 1             A12              48           A32     A43          5951
# 2             A14              12           A34     A46          2096
# 3             A11              42           A32     A42          7882
# 4             A11              24           A33     A40          4870
#
#   SavingAccounts PresentEmployment  InstallmentRate PersonalStatus  \
# 0            A65               A75                4            A93
# 1            A61               A73                2            A92
# 2            A61               A74                2            A93
# 3            A61               A74                2            A93
# 4            A61               A73                3            A93
#
#   OtherDebtors  ...  Property Age  OtherInstallmentPlans Housing  \
# 0         A101  ...      A121  67                   A143    A152
# ...

# %%
interval = (18, 25, 35, 60, 120)

cats = ['Student', 'Young', 'Adult', 'Senior']
df["Age_cat"] = pd.cut(df.Age, interval, labels=cats)


df_good = df[df["Class"] == 1]
df_bad = df[df["Class"] == 2]

# %%
# !pip install plotly

# %%
import plotly.offline as py 
py.init_notebook_mode(connected=True) # this code, allow us to work with offline plotly version
import plotly.graph_objs as go # it's like "plt" of matplot
import plotly.tools as tls # It's useful to we get some tools of plotly
import warnings # This library will be used to ignore some warnings
from collections import Counter # To do counter of some features

trace0 = go.Bar(
            x = df[df["Class"]== 1]["Class"].value_counts().index.values,
            y = df[df["Class"]== 1]["Class"].value_counts().values,
            name='Good credit'
    )

trace1 = go.Bar(
            x = df[df["Class"]== 2]["Class"].value_counts().index.values,
            y = df[df["Class"]== 2]["Class"].value_counts().values,
            name='Bad credit'
    )

data = [trace0, trace1]

layout = go.Layout(
    
)

layout = go.Layout(
    yaxis=dict(
        title='Count'
    ),
    xaxis=dict(
        title='Risk Variable'
    ),
    title='Target variable distribution'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='grouped-bar')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="0a20972e-b30b-45ac-871c-70c06a79b202" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0a20972e-b30b-45ac-871c-70c06a79b202")) {
#                     Plotly.newPlot(
# ...

# %%
trace0 = go.Box(
    y=df_good["CreditAmount"],
    x=df_good["Age_cat"],
    name='Good credit',
    marker=dict(
        color='#3D9970'
    )
)

trace1 = go.Box(
    y=df_bad['CreditAmount'],
    x=df_bad['Age_cat'],
    name='Bad credit',
    marker=dict(
        color='#FF4136'
    )
)
    
data = [trace0, trace1]

layout = go.Layout(
    yaxis=dict(
        title='Credit Amount (US Dollar)',
        zeroline=False
    ),
    xaxis=dict(
        title='Age Categorical'
    ),
    boxmode='group'
)
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='box-age-cat')
# Out:
# <div>
#
#
#             <div id="5e77c819-1dad-4ea9-b1ab-78e44fa988cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5e77c819-1dad-4ea9-b1ab-78e44fa988cc")) {
#                     Plotly.newPlot(
#                         '5e77c819-1dad-4ea9-b1ab-78e44fa988cc',
# ...

# %% [markdown]
# ### Approximately Good creditors have same distribution over age classes,
# ### It's clear from Box plot that, seniors and Adult have high % of being default

# %%
trace0 = go.Bar(
    x = df[df["Class"]== 1]["PersonalStatus"].value_counts().index.values,
    y = df[df["Class"]== 1]["PersonalStatus"].value_counts().values,
    name='Good credit'
)

#First plot 2
trace1 = go.Bar(
    x = df[df["Class"]== 2]["PersonalStatus"].value_counts().index.values,
    y = df[df["Class"]== 2]["PersonalStatus"].value_counts().values,
    name="Bad Credit"
)

#Second plot
trace2 = go.Box(
    x = df[df["Class"]== 1]["PersonalStatus"],
    y = df[df["Class"]== 1]["CreditAmount"],
    name=trace0.name
)

#Second plot 2
trace3 = go.Box(
    x = df[df["Class"]== 2]["PersonalStatus"],
    y = df[df["Class"]== 2]["CreditAmount"],
    name=trace1.name
)

data = [trace0, trace1, trace2,trace3]


fig = tls.make_subplots(rows=1, cols=2, 
                        subplot_titles=('Sex Count', 'Credit Amount by Sex'))

fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 2)

fig['layout'].update(height=400, width=800, title='Sex Distribuition', boxmode='group')
py.iplot(fig, filename='sex-subplot')
# Out:
# C:\Users\ahmed\Anaconda3\envs\tf_gpu\lib\site-packages\plotly\tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <div>
#
#
#             <div id="bd6ff5f3-1a15-49d5-8d39-48921c44f7de" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd6ff5f3-1a15-49d5-8d39-48921c44f7de")) {
#                     Plotly.newPlot(
#                         'bd6ff5f3-1a15-49d5-8d39-48921c44f7de',
# ...

# %% [markdown]
# ### Single Men have high % of classifying be Good Creditors ,
# ### however with respect to amount, Single Men have high amount of being defaultor

# %%
trace0 = go.Box(
    x=df_good["Job"],
    y=df_good["CreditAmount"],
    name='Good credit'
)

trace1 = go.Box(
    x=df_bad['Job'],
    y=df_bad['CreditAmount'],
    name='Bad credit'
)
    
data = [trace0, trace1]

layout = go.Layout(
    yaxis=dict(
        title='Credit Amount distribuition by Job'
    ),
    boxmode='group'
)
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='box-age-cat')
# Out:
# <div>
#
#
#             <div id="80a3200b-f30e-4031-9db8-cd7cd513aadd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80a3200b-f30e-4031-9db8-cd7cd513aadd")) {
#                     Plotly.newPlot(
#                         '80a3200b-f30e-4031-9db8-cd7cd513aadd',
# ...

# %% [markdown]
# ### Management and SelfEmployed(A174) have higher amount of Credit, and mostly classified as Defaultor

# %%
from plotly import tools
import numpy as np
import plotly.graph_objs as go

count_good = go.Bar(
    x = df_good["SavingAccounts"].value_counts().index.values,
    y = df_good["SavingAccounts"].value_counts().values,
    name='Good credit'
)
count_bad = go.Bar(
    x = df_bad["SavingAccounts"].value_counts().index.values,
    y = df_bad["SavingAccounts"].value_counts().values,
    name='Bad credit'
)


box_1 = go.Box(
    x=df_good["SavingAccounts"],
    y=df_good["CreditAmount"],
    name='Good credit'
)
box_2 = go.Box(
    x=df_bad["SavingAccounts"],
    y=df_bad["CreditAmount"],
    name='Bad credit'
)

scat_1 = go.Box(
    x=df_good["SavingAccounts"],
    y=df_good["Age"],
    name='Good credit'
)
scat_2 = go.Box(
    x=df_bad["SavingAccounts"],
    y=df_bad["Age"],
    name='Bad credit'
)

data = [scat_1, scat_2, box_1, box_2, count_good, count_bad]

fig = tools.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]],
                          subplot_titles=('Count Saving Accounts','Credit Amount by Savings Acc', 
                                          'Age by Saving accounts'))

fig.append_trace(count_good, 1, 1)
fig.append_trace(count_bad, 1, 1)

fig.append_trace(box_2, 1, 2)
fig.append_trace(box_1, 1, 2)

fig.append_trace(scat_1, 2, 1)
fig.append_trace(scat_2, 2, 1)



fig['layout'].update(height=700, width=800, title='Saving Accounts Exploration', boxmode='group')

py.iplot(fig, filename='combined-savings')
# Out:
# <div>
#
#
#             <div id="2a37d2de-949d-48a1-98ad-df8e09e8dbfa" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a37d2de-949d-48a1-98ad-df8e09e8dbfa")) {
#                     Plotly.newPlot(
#                         '2a37d2de-949d-48a1-98ad-df8e09e8dbfa',
# ...

# %% [markdown]
# ### Those having saving account with less than 100DM are good creditors
# ### Few having saving account with less than 100DM have applied for credit amount > 5000DM
# ### Majority of population around 30-40years, have applied for Credit

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
# checkingAccount          1000 non-null object
# DurationMonths           1000 non-null int64
# CreditHistory            1000 non-null object
# Purpose                  1000 non-null object
# CreditAmount             1000 non-null int64
# SavingAccounts           1000 non-null object
# PresentEmployment        1000 non-null object
# InstallmentRate          1000 non-null int64
# PersonalStatus           1000 non-null object
# OtherDebtors             1000 non-null object
# PresentResidence         1000 non-null int64
# Property                 1000 non-null object
# Age                      1000 non-null int64
# OtherInstallmentPlans    1000 non-null object
# Housing                  1000 non-null object
# ExistingCredits          1000 non-null int64
# Job                      1000 non-null object
# Liables                  1000 non-null int64
# ...

# %%
colnames=df.columns.to_list()

# %%
colnames
# Out:
# ['checkingAccount',
#  'DurationMonths',
#  'CreditHistory',
#  'Purpose',
#  'CreditAmount',
#  'SavingAccounts',
#  'PresentEmployment',
#  'InstallmentRate',
#  'PersonalStatus',
#  'OtherDebtors',
#  'PresentResidence',
#  'Property',
#  'Age',
#  'OtherInstallmentPlans',
#  'Housing',
#  'ExistingCredits',
#  'Job',
#  'Liables',
#  'Telephone',
#  'ForeignWorker',
#  'Class',
#  'Age_cat']

# %% [markdown]
# # Hypothesis
# ## H0: Credit rank is independent of Column attributes
# ## H1: Credit rank is dependent on Column attributes

# %%
categoricalColumns=['checkingAccount' , 'CreditHistory','Purpose',
         'SavingAccounts', 'PresentEmployment', 
          'PersonalStatus', 'OtherDebtors', 'Property',
         'OtherInstallmentPlans','Housing', 'Job',
         'Telephone','ForeignWorker']

# %%
from scipy import stats

# %%
count=0

for var in categoricalColumns:
    data_count=pd.crosstab(df[var],df["Class"]).reset_index()
    obs=np.asarray(data_count[[2,1]])
    chi2, p, dof, expected = stats.chi2_contingency(obs)
    count+=1
    if p<0.05:
        print(str(count)+" "+ var  +" have association with Credit ranking")
    else:
        print (str(count)+" "+ var +" have no assocication with credit ranking")
# Out:
# 1 checkingAccount have association with Credit ranking
# 2 CreditHistory have association with Credit ranking
# 3 Purpose have association with Credit ranking
# 4 SavingAccounts have association with Credit ranking
# 5 PresentEmployment have association with Credit ranking
# 6 PersonalStatus have association with Credit ranking
# 7 OtherDebtors have association with Credit ranking
# 8 Property have association with Credit ranking
# 9 OtherInstallmentPlans have association with Credit ranking
# 10 Housing have association with Credit ranking
# 11 Job have no assocication with credit ranking
# 12 Telephone have no assocication with credit ranking
# 13 ForeignWorker have association with Credit ranking

# %% [markdown]
# #### Credit Rank is independent of Job and Telephone, we can remove these

# %%
for attr in colnames:
    if df[attr].dtype=='object':
        df = df.merge(pd.get_dummies(df[attr], prefix=attr), left_index=True, right_index=True)
        df.drop(attr,axis=1,inplace=True)

# %%
colnames2=['ExistingCredits', 'Liables','PresentResidence']
for attr in colnames2:
    df = df.merge(pd.get_dummies(df[attr], prefix=attr), left_index=True, right_index=True)
    df.drop(attr,axis=1,inplace=True)

# %%
df
# Out:
#      DurationMonths  CreditAmount  InstallmentRate  Age  Class  Age_cat  \
# 0                 6          1169                4   67      1   Senior
# 1                48          5951                2   22      2  Student
# 2                12          2096                2   49      1    Adult
# 3                42          7882                2   45      1    Adult
# 4                24          4870                3   53      2    Adult
# ..              ...           ...              ...  ...    ...      ...
# 995              12          1736                3   31      1    Young
# 996              30          3857                4   40      1    Adult
# 997              12           804                4   38      1    Adult
# 998              45          1845                4   23      2  Student
# 999              45          4576                3   27      1    Young
#
#      checkingAccount_A11  checkingAccount_A12  checkingAccount_A13  \
# ...

# %% [markdown]
# # Model Implementation

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score # to split the data
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, fbeta_score #To evaluate our model
from sklearn.ensemble import RandomForestClassifier

# %%
df['CreditAmount'] = np.log(df['CreditAmount'])

# %%
df["CreditAmount"]
# Out:
# 0      7.063904
# 1      8.691315
# 2      7.647786
# 3      8.972337
# 4      8.490849
#          ...
# 995    7.459339
# 996    8.257645
# 997    6.689599
# 998    7.520235
# 999    8.428581
# Name: CreditAmount, Length: 1000, dtype: float64

# %%
#df=df.drop('Age_cat',1)
X = df.drop('Class', 1).values
y = df["Class"].values

# Spliting X and y into train and test version
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)

# %%
#df.drop("Age_cat",axis=1)

# %%
rf = RandomForestClassifier(max_depth=None, max_features=10, n_estimators=15, random_state=2)

#trainning with the best params
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features=10,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=15,
#                        n_jobs=None, oob_score=False, random_state=2, verbose=0,
#                        warm_start=False)

# %% [markdown]
# # Result and Confusion Matrix

# %%
y_pred = rf.predict(X_test)

# Verificaar os resultados obtidos
print(accuracy_score(y_test,y_pred))
print("\n")
print(confusion_matrix(y_test, y_pred))
print("\n")
print(fbeta_score(y_test, y_pred, beta=2))
# Out:
# 0.768
#
#
# [[157  21]
#  [ 37  35]]
#
#
# 0.8664459161147902
